# %% [markdown]
# <a href="https://colab.research.google.com/github/BarshaPanthi7/Danphe_task_Barsha/blob/main/notebooks/00_environment_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Environment setup

# %% [markdown]
# python environment

# %%
import sys

print("Python version:", sys.version)
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %% [markdown]
# Kaggle API Configuration

# %%
from google.colab import files

files.upload()

# %%
import os
import shutil

os.makedirs("/root/.config/kaggle", exist_ok=True)
shutil.move("/content/kaggle.json", "/root/.config/kaggle/kaggle.json")
os.chmod("/root/.config/kaggle/kaggle.json", 0o600)

print("Kaggle API configured successfully.")
# Out:
# Kaggle API configured successfully.

# %% [markdown]
# upgrading kaggle cli

# %%
# !pip install -q --upgrade kaggle
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.2/126.2 kB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.5/262.5 kB 3.6 MB/s eta 0:00:00

# %%
# !kaggle --version
# Out:
# Kaggle CLI 2.2.4

# %% [markdown]
# datset access

# %% [markdown]
# ptb-xl

# %%
# !kaggle datasets list -s ptbxl

# %%
# !kaggle datasets files -d physionet/ptbxl-electrocardiography-database

# %% [markdown]
# wesad

# %%
# !kaggle datasets list -s wesad

# %%
# !kaggle datasets files -d orvile/wesad-wearable-stress-affect-detection-dataset --page-size 200

# %% [markdown]
# iemocap

# %%
# !kaggle datasets list -s iemocap

# %%
# !kaggle datasets files -d dejolilandry/iemocapfullrelease --page-size 200
